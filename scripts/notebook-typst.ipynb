# %%
# Install all packages
# !uv add typst
# Out:
# Resolved 43 packages in 177ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)----     0 B/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 14.92 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 30.92 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 46.92 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 61.17 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 77.17 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 93.17 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 109.17 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 122.34 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 138.34 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 154.34 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 170.34 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 183.50 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 199.50 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 215.50 KiB/20.71 MiB
# ⠙ Preparing packages... (0/1)---- 231.50 KiB/20.71 MiB
# ...

# %%
import typst

# %%
typst.compile("templates/typst-template.typ", output="test.pdf")
